# %% [markdown]
# ### Day Objectives
# - Practice on Income Dataset
#   - Define functions for the following data points
#   - Average Income of all states from 2005 to 2013
#   - State with highest average income in the last three years
#   - State with lowest average income from 2007 to 2010(inclusive)
#   - Print the list of all states in the same line with average income less than California
#   - Print the names of states based on descending order of income in the year 2009
#   - State with the lowest recorded income from 2005 to 2013

# %%
# Function to read all the data from csv file
filepath="DataFiles/income.csv"
import pandas as pd
def readfile(filepath):
    return pd.read_csv(filepath)
readfile(filepath)
# Out:
#        GEOID       State   2005   2006   2007   2008   2009   2010   2011  \
# 0  04000US01     Alabama  37150  37952  42212  44476  39980  40933  42590
# 1  04000US02      Alaska  55891  56418  62993  63989  61604  57848  57431
# 2  04000US04     Arizona  45245  46657  47215  46914  45739  46896  48621
# 3  04000US05    Arkansas  36658  37057  40795  39586  36538  38587  41302
# 4  04000US06  California  51755  55319  55734  57014  56134  54283  53367
#
#     2012   2013
# 0  43464  41381
# 1  63648  61137
# 2  47044  50602
# 3  39018  39919
# 4  57020  57528

# %%
# Average Income of all states from 2005 to 2013

incomedf = readfile(filepath)
def average(df):
    k=[]
    for i in range(len(df.values[0::])):
        columns = df.values[i][2:]
        sum1=0
        c=0
        #print(columns)
        for column in columns:
            sum1+=column
        #print(sum1//len(df.values[0][2::]))
        print(df.values[i][1],(sum1//len(df.values[0][2::])))
       
    return 

average(incomedf)
# Out:
# Alabama 41126
# Alaska 60106
# Arizona 47214
# Arkansas 38828
# California 55350

# %%
#State with highest average income in the last three years

incomedf = readfile(filepath)
def highestaverage(df):
    l=[]
    d={}
    for i in range(len(df.values[0::])):
        columns = df.values[i][-3::]
        sum1=0
        c=0
        #print(columns)
        for column in columns:
            sum1+=column
        #print(sum1//len(df.values[0][2::]))
        #print(df.values[i][1],(sum1//len(df.values[0][-3::])))
        l.append((sum1//len(df.values[0][-3::])))
        d[df.values[i][1]]=l[i]
    for i in d.items():
        if i[1]==max(l):
            print(i[0],max(l))
            
    #print(max(l))
    #print(d.items())
       
    return 

highestaverage(incomedf)
# Out:
# Alaska 60738

# %%
# State with lowest average income from 2007 to 2010(inclusive)

incomedf = readfile(filepath)
def lowestaverage(df):
    l=[]
    d={}
    for i in range(len(df.values[0::])):
        columns = df.values[i][4:8]
        sum1=0
        c=0
        #print(columns)
        for column in columns:
            sum1+=column
        #print(sum1//len(df.values[0][2::]))
        #print(df.values[i][1],(sum1//len(df.values[0][-3::])))
        l.append((sum1//len(df.values[0][4:8])))
        d[df.values[i][1]]=l[i]
    for i in d.items():
        if i[1]==min(l):
            print(i[0],min(l))
            
    #print(max(l))
    #print(d.items())
       
    return 

lowestaverage(incomedf)
# Out:
# Arkansas 38876

# %%
# Print the list of all states in the same line with average income less than California

incomedf = readfile(filepath)
def averagelessthancal(df):
    l=[]
    d={}
    
    for i in range(len(df.values[0::])):
        columns = df.values[i][2:]
        sum1=0
        c=0
        #print(columns)
        for column in columns:
            sum1+=column
        #print(sum1//len(df.values[0][2::]))
        #print(df.values[i][1],(sum1//len(df.values[0][2::])))
            a=sum1//len(df.values[0][2::])
        l.append(a)
    #print(l)
        d[df.values[i][1]]=l[i]
    #print(d.items())
    value=0
    k=[]
    for i in d.items():
        if i[0]=="California":
            value=i[1]
    for i in range(len(l)):
        if value>l[i]:
            k.append(l[i])
    print(k)      
       
    return 

averagelessthancal(incomedf)
# Out:
# [41126, 48967, 38828]

# %%
# Print the names of states based on descending order of income in the year 2009

incomedf=readfile(filepath)

def descendingcolumn(df):
    l=[]
    d={}
    for i in range(len(df.values[0::])):
        columns=df.values[i][2]
        l.append(columns)
        d[df.values[i][1]]=l[i]
    l=sorted(l,reverse=True)
    #print(d.items())
    for j in range(len(df.values[0::])):
        for i in d.items():
            if i[1]==l[j]:
                print(i[0],l[j])
    return 
descendingcolumn(incomedf)
# Out:
# Alaska 55891
# California 51755
# Arizona 45245
# Alabama 37150
# Arkansas 36658

# %%
# State with the lowest recorded income from 2005 to 2013

def rowdata(df):
    l=[]
    d={}
    for i in range(len(df.values[0::])):
        columns=min((df.values[i][2::]))
        l.append(columns)
        d[df.values[i][1]]=l[i]
        #print(df.values[i][1])
        #print(l[i])
        
    for i in d.items():
        if i[1]==min(l):
            print(i[0],":",i[1])
    return
rowdata(incomedf)
# Out:
# Arkansas : 36538

# %%
incomedf
# Out:
#        GEOID       State   2005   2006   2007   2008   2009   2010   2011  \
# 0  04000US01     Alabama  37150  37952  42212  44476  39980  40933  42590
# 1  04000US02      Alaska  55891  56418  62993  63989  61604  57848  57431
# 2  04000US04     Arizona  45245  46657  62993  46914  45739  46896  48621
# 3  04000US05    Arkansas  36658  37057  40795  39586  36538  38587  41302
# 4  04000US06  California  51755  55319  55734  57014  56134  54283  53367
#
#     2012   2013
# 0  43464  41381
# 1  63648  61137
# 2  47044  50602
# 3  39018  39919
# 4  57020  57528
